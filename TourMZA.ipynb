# %% [markdown]
# # TourMZA: Asistente Inteligente para Planificar Visitas a Bodegas en Mendoza

# %% [markdown]
# ## Resumen
#
# Este proyecto propone el desarrollo de una Proof of Concept (POC) de un asistente inteligente para la planificación de visitas a bodegas en Mendoza...

# %% [markdown]
# ## Introducción
#
# ### Nombre del proyecto
# TourMZA: Asistente Inteligente para Planificar Visitas a Bodegas en Mendoza.
#
# ### Presentación del problema a abordar
# Mendoza es una de las capitales mundiales del vino...

# %% [markdown]
# ## Propuesta de solución
#
# La propuesta consiste en desarrollar un asistente inteligente basado en ingeniería de prompts...

# %% [markdown]
# ## Prompts Texto–Texto
#
# ### Prompt 1 – Clasificación de bodegas
#
# Actúa como guía turístico de Mendoza...

# %% [markdown]
# ### Prompt 2 – Generación de itinerario
#
# Crea un itinerario de bodegas...

# %% [markdown]
# ### Prompt 3 – Optimización por preferencias
#
# Propón tres itinerarios alternativos...

# %% [markdown]
# ## Prompts Texto–Imagen
#
# ### Prompt 4 – Imagen del recorrido
#
# Illustrated flat-style map of a wine tour...

# %% [markdown]
# ![Gemini_Generated_Image_wg0f86wg0f86wg0f.png](data:image/png;base64,...)

# %% [markdown]
# ## Objetivos
#
# ### Objetivo general
# ...
#
# ### Objetivos específicos
# ...

# %% [markdown]
# ## Metodología
#
# El proyecto se desarrolla mediante una metodología exploratoria...

# %% [markdown]
# ## Herramientas y tecnologías
#
# - ChatGPT
# - GitHub
# - Gemini

# %% [markdown]
# ## Implementación
#
# La implementación se realiza a través de una Jupyter Notebook...

# %% [markdown]
# ## Resultados
#
# La implementación permitió generar itinerarios claros...

# %% [markdown]
# ## Conclusiones
#
# El proyecto TourMZA demuestra que...
